# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf

# %%
tickerStrings = ["^GSPC"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df0 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df0["Daily Volatility"] = ((df0["High"]-df0["Low"])/(df0["Low"]))*100
df0 = df0[['Daily Volatility']]
df0.rename(columns={'Daily Volatility': 'Daily Volatility SYP'}, inplace=True)
df0
# Out:
#             Daily Volatility SYP
# Date
# 2022-01-03              0.808509
# 2022-01-04              0.928940
# 2022-01-05              2.090893
# 2022-01-06              1.150653
# 2022-01-07              0.969601
# ...                          ...
# 2022-12-20              1.122870
# 2022-12-21              1.310853
# 2022-12-22              2.358089
# 2022-12-23              1.284959
# 2022-12-27              0.876685
#
# [248 rows x 1 columns]

# %%
tickerStrings = ["^DJI"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df1 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df1["Daily Volatility"] = ((df1["High"]-df1["Low"])/(df1["Low"]))*100
df1 = df1[['Daily Volatility']]
df1.rename(columns={'Daily Volatility': 'Daily Volatility DOW'}, inplace=True)
df1
# Out:
#             Daily Volatility DOW
# Date
# 2022-01-03              0.963877
# 2022-01-04              0.815700
# 2022-01-05              1.517176
# 2022-01-06              0.727919
# 2022-01-07              0.751307
# ...                          ...
# 2022-12-20              1.049884
# 2022-12-21              1.240611
# 2022-12-22              2.025951
# 2022-12-23              1.255930
# 2022-12-27              0.962034
#
# [248 rows x 1 columns]

# %%
tickerStrings = ["^IXIC"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df2 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df2["Daily Volatility"] = ((df2["High"]-df2["Low"])/(df2["Low"]))*100
df2 = df2[['Daily Volatility']]
df2.rename(columns={'Daily Volatility': 'Daily Volatility NASDAQ'}, inplace=True)
df2
# Out:
#             Daily Volatility NASDAQ
# Date
# 2022-01-03                 1.206270
# 2022-01-04                 2.190050
# 2022-01-05                 3.253490
# 2022-01-06                 1.901324
# 2022-01-07                 1.972019
# ...                             ...
# 2022-12-20                 1.556834
# 2022-12-21                 1.744409
# 2022-12-22                 2.773302
# 2022-12-23                 1.475990
# 2022-12-27                 1.272539
#
# [248 rows x 1 columns]

# %%
tickerStrings = ["DX-Y.NYB"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df3 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df3["Daily Volatility"] = ((df3["High"]-df3["Low"])/(df3["Low"]))*100
df3 = df3[['Daily Volatility']]
df3.rename(columns={'Daily Volatility': 'Daily Volatility DOLLAR'}, inplace=True)
df3
# Out:
#             Daily Volatility DOLLAR
# Date
# 2022-01-03                 0.731993
# 2022-01-04                 0.447777
# 2022-01-05                 0.458862
# 2022-01-06                 0.364430
# 2022-01-07                 0.616450
# ...                             ...
# 2022-12-20                 0.973215
# 2022-12-21                 0.510350
# 2022-12-22                 0.819276
# 2022-12-23                 0.403379
# 2022-12-27                 0.490906
#
# [252 rows x 1 columns]

# %%
tickerStrings = ["EURUSD=X"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df4 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df4["Daily Volatility"] = ((df4["High"]-df4["Low"])/(df4["Low"]))*100
df4 = df4[['Daily Volatility']]
df4.rename(columns={'Daily Volatility': 'Daily Volatility EURUSD'}, inplace=True)
df4
# Out:
#             Daily Volatility EURUSD
# Date
# 2022-01-03                 0.802006
# 2022-01-04                 0.439554
# 2022-01-05                 0.602450
# 2022-01-06                 0.399969
# 2022-01-07                 0.613431
# ...                             ...
# 2022-12-21                 0.438509
# 2022-12-22                 0.693798
# 2022-12-23                 0.408239
# 2022-12-26                 0.265938
# 2022-12-27                 0.532915
#
# [257 rows x 1 columns]

# %%
tickerStrings = ["JPY=X"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df5 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df5["Daily Volatility"] = ((df5["High"]-df5["Low"])/(df5["Low"]))*100
df5 = df5[['Daily Volatility']]
df5.rename(columns={'Daily Volatility': 'Daily Volatility JPYUSD'}, inplace=True)
df5
# Out:
#             Daily Volatility JPYUSD
# Date
# 2022-01-03                 0.335729
# 2022-01-04                 0.902864
# 2022-01-05                 0.525830
# 2022-01-06                 0.453942
# 2022-01-07                 0.379783
# ...                             ...
# 2022-12-21                 0.725350
# 2022-12-22                 0.779310
# 2022-12-23                 0.627406
# 2022-12-26                 0.685406
# 2022-12-27                 0.707897
#
# [257 rows x 1 columns]

# %%
tickerStrings = ["^TNX"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df6 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df6["Daily Volatility"] = ((df6["High"]-df6["Low"])/(df6["Low"]))*100
df6 = df6[['Daily Volatility']]
df6.rename(columns={'Daily Volatility': 'Daily Volatility TBOND'}, inplace=True)
df6
# Out:
#             Daily Volatility TBOND
# Date
# 2022-01-03                6.653620
# 2022-01-04                1.934700
# 2022-01-05                3.825142
# 2022-01-06                1.336432
# 2022-01-07                4.284887
# ...                            ...
# 2022-12-20                1.313985
# 2022-12-21                2.098867
# 2022-12-22                1.233886
# 2022-12-23                1.569691
# 2022-12-27                1.980461
#
# [248 rows x 1 columns]

# %%
tickerStrings = ["^VIX"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df7 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df7["Daily Volatility"] = ((df7["High"]-df7["Low"])/(df7["Low"]))*100
df7 = df7[['Daily Volatility']]
df7.rename(columns={'Daily Volatility': 'Daily Volatility VIX'}, inplace=True)
df7
# Out:
#             Daily Volatility VIX
# Date
# 2022-01-03             11.956531
# 2022-01-04              8.996324
# 2022-01-05             21.652595
# 2022-01-06             10.377356
# 2022-01-07             12.008614
# ...                          ...
# 2022-12-20              9.555030
# 2022-12-21              6.770313
# 2022-12-22             21.439275
# 2022-12-23              8.950908
# 2022-12-27              5.604442
#
# [248 rows x 1 columns]

# %%
tickerStrings = ["GC=F"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df8 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df8["Daily Volatility"] = ((df8["High"]-df8["Low"])/(df8["Low"]))*100
df8 = df8[['Daily Volatility']]
df8.rename(columns={'Daily Volatility': 'Daily Volatility GOLD'}, inplace=True)
df8
# Out:
#             Daily Volatility GOLD
# Date
# 2022-01-03               1.740045
# 2022-01-04               0.850003
# 2022-01-05               0.634273
# 2022-01-06               0.235022
# 2022-01-07               0.706118
# ...                           ...
# 2022-12-20               1.953542
# 2022-12-21               0.385802
# 2022-12-22               1.854340
# 2022-12-23               0.484927
# 2022-12-27               1.269825
#
# [248 rows x 1 columns]

# %%
tickerStrings = ["CL=F"]

# %%
#Building our Dataframe
#I use the following function to create our Dataframe with the tickets I want
df_list = list()
for ticker in tickerStrings:
    data = yf.download(ticker, start="2022-01-01", end="2022-12-28", group_by="Column")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    df_list.append(data)

# combine all dataframes into a single dataframe
df9 = pd.concat(df_list)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df9["Daily Volatility"] = ((df9["High"]-df9["Low"])/(df9["Low"]))*100
df9 = df9[['Daily Volatility']]
df9.rename(columns={'Daily Volatility': 'Daily Volatility WTI'}, inplace=True)
df9
# Out:
#             Daily Volatility WTI
# Date
# 2022-01-03              2.948704
# 2022-01-04              2.562751
# 2022-01-05              2.705528
# 2022-01-06              4.574475
# 2022-01-07              2.483450
# ...                          ...
# 2022-12-20              3.283545
# 2022-12-21              3.707121
# 2022-12-22              3.725825
# 2022-12-23              3.013591
# 2022-12-27              2.551789
#
# [249 rows x 1 columns]

# %%
d = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7, df8, df9], axis=1)
d.head()
# Out:
#             Daily Volatility SYP  Daily Volatility DOW  \
# Date
# 2022-01-03              0.808509              0.963877
# 2022-01-04              0.928940              0.815700
# 2022-01-05              2.090893              1.517176
# 2022-01-06              1.150653              0.727919
# 2022-01-07              0.969601              0.751307
#
#             Daily Volatility NASDAQ  Daily Volatility DOLLAR  \
# Date
# 2022-01-03                 1.206270                 0.731993
# 2022-01-04                 2.190050                 0.447777
# 2022-01-05                 3.253490                 0.458862
# 2022-01-06                 1.901324                 0.364430
# 2022-01-07                 1.972019                 0.616450
#
#             Daily Volatility EURUSD  Daily Volatility JPYUSD  \
# Date
# 2022-01-03                 0.802006                 0.335729
# 2022-01-04                 0.439554                 0.902864
# 2022-01-05                 0.602450                 0.525830
# 2022-01-06                 0.399969                 0.453942
# 2022-01-07                 0.613431                 0.379783
#
#             Daily Volatility TBOND  Daily Volatility VIX  \
# Date
# 2022-01-03                6.653620             11.956531
# 2022-01-04                1.934700              8.996324
# 2022-01-05                3.825142             21.652595
# 2022-01-06                1.336432             10.377356
# 2022-01-07                4.284887             12.008614
#
#             Daily Volatility GOLD  Daily Volatility WTI
# Date
# 2022-01-03               1.740045              2.948704
# 2022-01-04               0.850003              2.562751
# 2022-01-05               0.634273              2.705528
# 2022-01-06               0.235022              4.574475
# 2022-01-07               0.706118              2.483450

# %%
d.isnull().sum()
# Out:
# Daily Volatility SYP       9
# Daily Volatility DOW       9
# Daily Volatility NASDAQ    9
# Daily Volatility DOLLAR    5
# Daily Volatility EURUSD    0
# Daily Volatility JPYUSD    0
# Daily Volatility TBOND     9
# Daily Volatility VIX       9
# Daily Volatility GOLD      9
# Daily Volatility WTI       8
# dtype: int64

# %%
d = d.apply(lambda x: x.fillna(x.mean()),axis=0)
d.isnull().sum()
# Out:
# Daily Volatility SYP       0
# Daily Volatility DOW       0
# Daily Volatility NASDAQ    0
# Daily Volatility DOLLAR    0
# Daily Volatility EURUSD    0
# Daily Volatility JPYUSD    0
# Daily Volatility TBOND     0
# Daily Volatility VIX       0
# Daily Volatility GOLD      0
# Daily Volatility WTI       0
# dtype: int64

# %%
#We have a problem, the index is wrong defined.
#We change the Index and add the "Date" column into our Dataframe
d.reset_index(inplace=True)
d = d.rename(columns = {'index':''})
d.head()
# Out:
#         Date  Daily Volatility SYP  Daily Volatility DOW  \
# 0 2022-01-03              0.808509              0.963877
# 1 2022-01-04              0.928940              0.815700
# 2 2022-01-05              2.090893              1.517176
# 3 2022-01-06              1.150653              0.727919
# 4 2022-01-07              0.969601              0.751307
#
#    Daily Volatility NASDAQ  Daily Volatility DOLLAR  Daily Volatility EURUSD  \
# 0                 1.206270                 0.731993                 0.802006
# 1                 2.190050                 0.447777                 0.439554
# 2                 3.253490                 0.458862                 0.602450
# 3                 1.901324                 0.364430                 0.399969
# 4                 1.972019                 0.616450                 0.613431
#
#    Daily Volatility JPYUSD  Daily Volatility TBOND  Daily Volatility VIX  \
# 0                 0.335729                6.653620             11.956531
# 1                 0.902864                1.934700              8.996324
# 2                 0.525830                3.825142             21.652595
# 3                 0.453942                1.336432             10.377356
# 4                 0.379783                4.284887             12.008614
#
#    Daily Volatility GOLD  Daily Volatility WTI
# 0               1.740045              2.948704
# 1               0.850003              2.562751
# 2               0.634273              2.705528
# 3               0.235022              4.574475
# 4               0.706118              2.483450

# %%
datacorr = d.drop('Date', axis=1)

# %%
#Correlation for Stock Prices (Using Daily Volatility Column)
datacorr.columns = ["SYP500", "DOW", "NASDAQ", "DOLLAR", "EURUSD", "USDJPY", "TBOND", "VIX", "GOLD", "WTI"]

# %%
heatmap = sns.heatmap(datacorr.corr().round(2), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Daily Volatility Assets', fontdict={'fontsize':12}, pad=12);
